# %% [markdown]
# <a href="https://colab.research.google.com/github/AyseNil-star/AyseNil-star/blob/main/copy_of_untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=1
print(a)
# Out:
# 1

# %% [markdown]
# This is just demo

# %%
type(10)
# Out:
# int

# %%
import sys
print ("python version is: ", sys .version)
# Out:
# python version is:  3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
""" if we write long comment
fddrtzdrtzrdtzdrztdrzt
rtsrtsrtsrtsertsertsrtstr"""

# %%
# if we write variable and than write . dot than different process is opened
a.bit_count
# Out:
# <function int.bit_count()>

# %%
name= "Ayse Nil"
name*2
# Out:
# 'Ayse NilAyse Nil'

# %%
x= input("enter x:")
# Out:
# enter x:21

# %%
del(x)   #Bir degiskeni degistirmek istiyorsak

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-32546335.py in <cell line: 0>()
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
name
# Out:
# 'Ayse Nil'
